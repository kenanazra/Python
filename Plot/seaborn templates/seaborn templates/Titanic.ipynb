# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic.describe(include='all')
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# ...

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic['embarked'] =titanic['embarked'].fillna('S')
#titanic.info()
titanic['embarked'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 891 entries, 0 to 890
# Series name: embarked
# Non-Null Count  Dtype
# --------------  -----
# 891 non-null    object
# dtypes: object(1)
# memory usage: 7.1+ KB

# %%
titanic =titanic.drop(columns='embark_town')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck alive  alone
# ...

# %%
titanic =titanic.drop(columns=['class','deck','alive'])
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked    who  \
# 0           0       3    male  22.0      1      0   7.2500        S    man
# 1           1       1  female  38.0      1      0  71.2833        C  woman
# 2           1       3  female  26.0      0      0   7.9250        S  woman
# 3           1       1  female  35.0      1      0  53.1000        S  woman
# 4           0       3    male  35.0      0      0   8.0500        S    man
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 886         0       2    male  27.0      0      0  13.0000        S    man
# 887         1       1  female  19.0      0      0  30.0000        S  woman
# 888         0       3  female   NaN      1      2  23.4500        S  woman
# 889         1       1    male  26.0      0      0  30.0000        C    man
# 890         0       3    male  32.0      0      0   7.7500        Q    man
#
#      adult_male  alone
# 0          True  False
# ...

# %%
titanic['age']= titanic['age'].fillna(titanic['age'].mean())

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   survived    891 non-null    int64
#  1   pclass      891 non-null    int64
#  2   sex         891 non-null    object
#  3   age         891 non-null    float64
#  4   sibsp       891 non-null    int64
#  5   parch       891 non-null    int64
#  6   fare        891 non-null    float64
#  7   embarked    891 non-null    object
#  8   who         891 non-null    object
#  9   adult_male  891 non-null    bool
#  10  alone       891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(3)
# memory usage: 64.5+ KB

# %%
titanic.value_counts(titanic['who'])
# Out:
# who
# man      537
# woman    271
# child     83
# Name: count, dtype: int64

# %%
titanic['pclass'] =titanic['pclass'].astype('object')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   survived    891 non-null    int64
#  1   pclass      891 non-null    object
#  2   sex         891 non-null    object
#  3   age         891 non-null    float64
#  4   sibsp       891 non-null    int64
#  5   parch       891 non-null    int64
#  6   fare        891 non-null    float64
#  7   embarked    891 non-null    object
#  8   who         891 non-null    object
#  9   adult_male  891 non-null    bool
#  10  alone       891 non-null    bool
# dtypes: bool(2), float64(2), int64(3), object(4)
# memory usage: 64.5+ KB

# %% [markdown]
# ### pclass und survived

# %%
sns.barplot(x ='pclass',y='survived',data=titanic)
# Out:
# <Axes: xlabel='pclass', ylabel='survived'>

# %%
sns.barplot(x ='sex',y='survived',data=titanic)
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
sns.scatterplot(x ='survived',y='fare',data=titanic,hue='pclass')
# Out:
# <Axes: xlabel='survived', ylabel='fare'>

# %%
sns.barplot(x ='who',y='survived',data=titanic,hue='pclass')
# Out:
# <Axes: xlabel='who', ylabel='survived'>

# %% [markdown]
# ## dose (age) affect the (survived) value?

# %%
age_number = titanic['age'].value_counts()
age_number
# Out:
# age
# 29.699118    177
# 24.000000     30
# 22.000000     27
# 18.000000     26
# 28.000000     25
#             ...
# 36.500000      1
# 55.500000      1
# 0.920000       1
# 23.500000      1
# 74.000000      1
# Name: count, Length: 89, dtype: int64

# %%
titanic.groupby('survived')['age'].count()
# Out:
# survived
# 0    549
# 1    342
# Name: age, dtype: int64

# %%
sns.barplot(x ='survived',y='age',data=titanic)
plt.show()

# %% [markdown]
# wie im Diagram steht:junge leute sind mehr als alte leute überleben

# %% [markdown]
# ## dose (alone) affect the (survived) feature

# %%
alone_number = titanic['alone'].value_counts()
alone_number
# Out:
# alone
# True     537
# False    354
# Name: count, dtype: int64

# %%
titanic.groupby('survived')['alone'].count()
# Out:
# survived
# 0    549
# 1    342
# Name: alone, dtype: int64

# %%
sns.barplot(x ='alone',y='survived',data=titanic)
plt.show()

# %% [markdown]
# ## q 6: wat is the number of passenger of each class

# %%
passenger_number = titanic['pclass'].value_counts()
passenger_number
# Out:
# pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %% [markdown]
# ## q7: Dose the embark town has a relactionship with(survived)

# %%
titanic.groupby('embarked')['survived'].count()
# Out:
# embarked
# C    168
# Q     77
# S    646
# Name: survived, dtype: int64

# %%
sns.barplot(x ='embarked',y='survived',data=titanic)
#plt.xticks(rotation=45)
plt.show()
